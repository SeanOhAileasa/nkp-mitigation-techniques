# %% [markdown]
# ***
# < [Home](https://github.com/SeanOhAileasa) | [README](https://github.com/SeanOhAileasa/nkp-mitigation-techniques/blob/main/README.md) >
#
# ## CompTIA Network+ - Course Material 2022
# ### Topic: ``Mitigation Techniques``
# ***

# %% [markdown]
# Course material for the ``CompTIA Network+`` module of the ``ICT Associate Apprenticeship (Cybersecurity)`` programme.

# %% [markdown]
# <a id="top"></a>
# ***
# ## Table of Contents
# ***

# %% [markdown]
# ###### Quick Links
# ***
#
# * [Mitigation Techniques](#topmitigationTechniques)&nbsp;&nbsp;|&nbsp;&nbsp;[Test](#topmitigationTechniquesTest)

# %% [markdown]
# <hr width=50%;>

# %% [markdown]
# <a id="topmitigationTechniques"></a>
# ### [Mitigation Techniques](#mitigationTechniques)
#
# - [1. Course Introduction](#mitigationTechniques1CourseIntroduction) <br/><br/>
# - [2. Signature Management](#mitigationTechniques2SignatureManagement) <br/><br/>
# - [3. Device and Host Hardening](#mitigationTechniques3DeviceandHostHardening) <br/><br/>
# - [4. VLAN](#mitigationTechniques4VLAN) <br/><br/>
# - [5. Switch Port Configuration](#mitigationTechniques5SwitchPortConfiguration) <br/><br/>
# - [6. Switch Port Protection](#mitigationTechniques6SwitchPortProtection) <br/><br/>
# - [7. Network Segmentation](#mitigationTechniques7NetworkSegmentation) <br/><br/>
# - [8. Privileged User Accounts](#mitigationTechniques8PrivilegedUserAccounts) <br/><br/>
# - [9. File Integrity](#mitigationTechniques9FileIntegrity) <br/><br/>
# - [10. Role Separation](#mitigationTechniques10RoleSeparation) <br/><br/>
# - [11. Access Control Lists](#mitigationTechniques11AccessControlLists) <br/><br/>
# - [12. Honeypots](#mitigationTechniques12Honeypots) <br/><br/>
# - [13. Penetration Testing](#mitigationTechniques13PenetrationTesting)

# %% [markdown]
# ### [Practice: Using Mitigation Techniques](#practicemitigationTechniques)
#
# * [1. Exercise: Using Mitigation Techniques](#exercisemitigationTechniques)

# %% [markdown]
# <a id="topmitigationTechniquesTest"></a>
# ### ⚡ [Test](#mitigationTechniquesTest)

# %% [markdown]
# <hr width=50%;>

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="mitigationTechniques"></a>
# ***
# ### Mitigation Techniques
# ***

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="mitigationTechniques1CourseIntroduction"></a>
# ***
# ###### 1. Course Introduction
# ***

# %% [markdown]
#  Course covers some common threat mitigation techniques such as Role Separation, Penetration Testing and Honeypots.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="mitigationTechniques2SignatureManagement"></a>
# ***
# ###### 2. Signature Management
# ***

# %% [markdown]
# After completing this topic, you should be able to: ``describe signature management``

# %% [markdown]
# Now, we'll begin this course with a look at what a virus signature is.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Virus Signature
# ***

# %% [markdown]
# And this is quite simply a string of characters or numbers that is assigned to any given virus as a means of identifying it so that antivirus programs and/or possibly intrusion detection systems can pick up on the presence of that threat because it recognizes the signature.

# %% [markdown]
# Now, signatures use algorithms or hashes to uniquely identify a specific virus. But in fact, multiple viruses can share a single signature. Because in many cases, there are, quite simply, different strains of the same virus. So by picking up on that single signature, it might actually be able to pick up on the varieties of strains that might be out there. Because they do share the same core, if you will. And that's what the antivirus program looks for. So it allows it to pick up on these variations.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Antivirus Vendors
# ***

# %% [markdown]
# So when it comes to the antivirus vendors, they issue the signatures and they release them on an ongoing basis and often within hours of new threats being discovered. And if you're curious as to how they are able to pick up on these threats so quickly, they quite literally implement data centers where people do little more then attempt to infect their systems intentionally.

# %% [markdown]
# They are doing everything that they can on the Internet that would normally be considered risky or dangerous when it comes to getting a virus.

# %% [markdown]
# So they do everything possible to try to contract them, and this helps them to keep on top of anything that is picked up. And, of course, they rely on the installations of their own software as well to report back if they discover something that does seem to be at least a little bit suspicious. They might not recognize any given virus by its signature because it could be brand new. But in many cases, they are still able to pick up on things that are suspicious, if you will. And in fact, that goes along with the next point here, that it's not always just signature management.

# %% [markdown]
# Vendors are also offering solutions such as file reputation and heuristics-based engines.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### File Reputation
# ***

# %% [markdown]
# Now, file reputation, in essence, can track a file as it goes through changes, as it moves through your environment and, in essence, can learn what is normal with respect to the changes that might occur.

# %% [markdown]
# But any kind of infection is a change. So if a change happens that seems to be outside of the norm, then that is considered to be suspicious and it can be reported.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Heuristics-based Engines
# ***

# %% [markdown]
# Heuristics-based engines, basically, don't rely on signatures. They, quite literally, try to apply almost a human logic to determine whether or not there is anything wrong with this file.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Signatures
# ***

# %% [markdown]
# So signatures are by no means 100%. They're certainly very effective for known viruses, but of course, new viruses that just come out will not have a signature.

# %% [markdown]
# So they need to be captured by some other means, and then they will likely be given a signature. But, of course, if has to be captured in the first place.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Management
# ***

# %% [markdown]
# Now with respect to management, you will almost always find in a corporate environment some kind of centralized antivirus management implementation.

# %% [markdown]
# This allows for very granular control over the client systems with respect to how and when they receive their updates, as well as ensuring that they are all configured consistently.

# %% [markdown]
# An administrator can sit at a server, that is, the management server, and define policies. And this one policy, or a few different ones, can then be deployed to all of the client systems so that they have the same configuration.

# %% [markdown]
# They are set to scan with the same settings. They are set to check for updates at the same time. So this way you know that all of your systems are protected and they have this consistent configuration.

# %% [markdown]
# You can also use those applications to monitor the users on a network. So you can find out if everyone has the same and the most up-to-date version.

# %% [markdown]
# You can receive alerts when any kind of infection is detected or how widespread it is.

# %% [markdown]
# And, of course, you can update the virus signatures from the central management server and then deploy those updates to the client.

# %% [markdown]
# So, again, this is something that you definitely see in most corporate environments.

# %% [markdown]
# For home users, you generally just install the software. And, of course, you can configure it however you like. But it's still important to ensure that it is set to scan. And, of course, set to automatically go out and check for updates.

# %% [markdown]
# So the administrators can push out new signature updates to the clients on a network, as mentioned. And in many cases, you have a point and click graphic user interface to do this from. But you might also have the ability to script it. And this might be an option depending on how similar all of your systems are. If you have quite a mix of different operating systems and different types of devices, you might need to script something just for compatibility reasons.

# %% [markdown]
# But if everything is fairly consistent, you generally can just use a graphic interface and say, here are the updates. And again, you configure the clients with their policies to check for the updates on a regularly scheduled basis.

# %% [markdown]
# But you can, in many cases, also force them to check right now. If, for example, you just received new updates and you know that their update cycle is maybe to only check every three days, and let's say you just got these updates today but you know they checked yesterday, then you know it's going to be two more days before they check again. So you can, in essence, force them to refresh and get the new updates.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Automated Update Services
# ***

# %% [markdown]
# Now the automated update services, in essence, are what the vendor themselves provide with respect to when they release the updates.

# %% [markdown]
# So your management server can periodically check with the vendor for new signatures or any kind of program upgrade.

# %% [markdown]
# So, again, it's up to you as an administrator to determine when your management server goes out to check for the updates.

# %% [markdown]
# It usually gets them, pulls them down, then you distribute them to the clients.

# %% [markdown]
# But it might also be a new version of the software itself to address any kind of stability issues, or compatibility issues, things along those lines. But, ultimately, when you do implement any kind of antivirus solution in your environment, this type of enterprise configuration allows much greater control and much greater consistency for the way the client systems are protected.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="mitigationTechniques3DeviceandHostHardening"></a>
# ***
# ###### 3. Device and Host Hardening
# ***

# %% [markdown]
# After completing this topic, you should be able to: ``describe device and host hardening``

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Host Hardening
# ***

# %% [markdown]
# Now, when it comes to mitigating threats, one of the simplest, but yet most effective defenses is to implement what's known as host hardening.

# %% [markdown]
# Now, that's a fairly generalized term with respect to what a host is, but it does mean quite literally just about anything that can obtain an IP address. So, a desktop system, a laptop, a server, a mobile device, even a router or a firewall or even a printer. Just about anything that can be accessed.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Default Passwords
# ***

# %% [markdown]
# But when it comes to the configuration of many devices, there are a lot of things that are present by default. And as such, they're fairly well known, and that includes attackers.

# %% [markdown]
# They know about these configurations because they are so common. So on many devices there are things like default passwords. There are default accounts that are in place.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Deactivating Default Accounts
# ***

# %% [markdown]
# So it's recommended to change these passwords and/or to deactivate some of those accounts. Because they are so well known, they provide a point of attack in many cases that will be very easy to compromise.

# %% [markdown]
# For example, a Windows desktop system, just a client, always has an account known as the local administrator account. And if you just set that system up out of the box and you just kind of next, next, next through the initial configuration. In many cases, you can end up with a system that has the administrator account activated with no password.

# %% [markdown]
# So there is a very easy way for someone to be able to gain access to that system. And then they might be able to use that system to attack other systems for example.

# %% [markdown]
# But that administrator account is very well known, of course, to attackers. So by deactivating it and/or leaving it activated but changing the password makes it more difficult for them to gain access.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Patches
# ***

# %% [markdown]
# Also, of course, applying patches, keeping the software and any associated hardware up to date. And that might also include firmware, of course, the software that is directly installed on the hardware.

# %% [markdown]
# But in many cases, patches are specifically designed to address a known vulnerability. So keeping everything up to date is another very good approach.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Disable Unnecessary Services
# ***

# %% [markdown]
# Now, you might also want to disable any unnecessary services.

# %% [markdown]
# And this is very common on servers. Any one server can provide any number of services to the clients.

# %% [markdown]
# So if you simply do not use server X for this service, this service, and that service, then disable them because they also represent means to access that server and possibly compromise it.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Implement Vulnerability Assessment
# ***

# %% [markdown]
# So implementing a vulnerability assessment is essentially the process of trying to identify vulnerabilities and weaknesses.

# %% [markdown]
# And you can do this for a single host or you can in some cases, scan an entire network.

# %% [markdown]
# But the idea is to try to find out where are the vulnerabilities so that we can implement host hardening on those systems to try to tighten up the security.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Security Templates
# ***

# %% [markdown]
# Now in many cases what you can also do is to implement security templates across one or multiple systems.

# %% [markdown]
# And the templates are simply preset, preconfigured values. So if you want server X to supply a particular type of service, there might be a template for that. And that of course would allow the necessary service, but automatically shut down those that are deemed to be unnecessary.

# %% [markdown]
# Now the templates aren't set in stone. You can still alter the configuration after the template has been applied.

# %% [markdown]
# For example, maybe you do need another service or maybe there are some other ones that you feel should be shut down. But they give you these good consistent starting points so that you know that this is the basic configuration. Then we can tweak as needed.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Group Policy
# ***

# %% [markdown]
# And along those lines, group policy is another very effective method if you are in a Windows environment.

# %% [markdown]
# These allow you to configure just about any Windows setting, and then deploy those settings to one or many computers.

# %% [markdown]
# And the numbers there really are unlimited. It can be a single system or every system in the entire environment.

# %% [markdown]
# But the idea is that you know that all of the systems are set consistently. They all have the same configuration.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Conclusion - Reliable Enviroment
# ***

# %% [markdown]
# So if you are at least fairly confident that you have addressed the vulnerabilities with that particular configuration. Once it's deployed, you know that all of these systems will have that configuration. And of course this results in a much more secure and a much more reliable environment.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="mitigationTechniques4VLAN"></a>
# ***
# ###### 4. VLAN
# ***

# %% [markdown]
# After completing this topic, you should be able to: ``recognize when to change native VLANs``

# %% [markdown]
# Now in this presentation, we'll take a look at some VLAN configuration options.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### VLAN Configuration Options
# ***

# %% [markdown]
# As, these days, many Layer 2 switches allow you to group the physical switch ports into logical virtual LANs, or VLANs.

# %% [markdown]
# And each VLAN on a switch represents an individual broadcast domain.

# %% [markdown]
# So, for example, a broadcast on a switch port belonging to VLAN 1 will not be seen on a switch port belonging to VLAN 2.

# %% [markdown]
# Now, also be aware that a VLAN can exist on more than one switch.

# %% [markdown]
# In other words, you can go in both directions. If, for example, you have a single switch, and let's just say there were 24 ports, you could absolutely create two VLANs of 12 each within that single switch. Or you could go the other way. If you had two physical switches, each with 24 ports, you'd have 48 in total, you could create a single VLAN out of all 48. That's entirely up to you.

# %% [markdown]
# Now in most IP environments, each VLAN is usually associated with an IP subnet, but that's just common, it's not required. But once you do have your subnets defined and mapped to the VLANs, then traffic does need to be routed to get any traffic from one VLAN to another. Because, of course, once it is a separate IP subnet, to get to another IP subnet, it does have to be routed. But, again, that's just common. You could take a single subnet and divide it into multiple smaller VLANs. In other words, segment that subnet if you want to. Again, the configuration is up to you.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### VLAN Trunking Protocol - VTP
# ***

# %% [markdown]
# Now the VLAN trunking protocol, or VTP, allows VLAN changes on one switch to be dynamically advertised to adjacent switches via the trunk links.

# %% [markdown]
# You can implement a VTP server which can be used to add, delete, or modify the VLAN information.

# %% [markdown]
# And that information is then propagated over the trunk links and learned by other VTP servers and VTP clients.

# %% [markdown]
# And this just allows you to centralize the management. So if you have a particularly dynamic environment, I can centrally control the configuration of all the VLANs from the VTP server. And this, of course, allows me to push out those changes, if you will, very easily.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Native versus Default VLANs
# ***

# %% [markdown]
# Now when it comes to the native versus the default VLAN, there's just a little bit of terminology, really, that needs to be clarified here.

# %% [markdown]
# In most cases, you'll hear people refer to native and/or default as meaning the same thing.

# %% [markdown]
# But a native VLAN, in essence, is defined by the 802.1Q specification, wherein one VLAN in the trunk is known as the native VLAN.

# %% [markdown]
# And, as such, the native VLAN does not receive any tagging, but all other VLANs do receive a tag.

# %% [markdown]
# And the tag is embedded in one of the four extra bytes that are prepended to each Ethernet frame in a non-native VLAN.

# %% [markdown]
# So the native VLAN, in essence, exists by default.

# %% [markdown]
# So, again, they are very similar terms, but VLAN 1 is always the default VLAN and is mandatory. And this is needed for many protocol communications between switches, such as the Spanning-Tree Protocol, which we'll actually talk about in the next presentation.

# %% [markdown]
# But just coming back to that native versus default, again, the native VLAN is always there. But in terms of the behavior of the packets that are being switched, if there is a tag, then that indicates which VLAN the packet is destined for.

# %% [markdown]
# If there is no tag, then it will, by default, be sent to the native VLAN.

# %% [markdown]
# So that, again, is just simply a little bit of terminology. The VLAN itself is referred to as the native VLAN, but the switching behavior is for untagged packets to be delivered by default to the native VLAN.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Conclusion - Native versus Default VLANs
# ***

# %% [markdown]
# So, again, most people will probably use those terms somewhat interchangeably. But one refers to the VLAN itself. One refers to the switching behavior when it comes to those untagged packets.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Conclusion - VLAN Configuration
# ***

# %% [markdown]
# So, ultimately, it's up to you how you configure your VLANs. But, again, things like the native and the VTP server can certainly help you ease the configuration and determine where your VLANs are going to reside.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="mitigationTechniques5SwitchPortConfiguration"></a>
# ***
# ###### 5. Switch Port Configuration
# ***

# %% [markdown]
# After completing this topic, you should be able to: ``recognize switch port configuration using the Spanning Tree Protocol, BPDU guard, and root guard``

# %% [markdown]
# In this presentation we'll introduce a Switch Configuration Protocol known as STP, or the Spanning Tree Protocol.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Spanning Tree Protocol (STP)
# ***

# %% [markdown]
# Now this is something that is implemented when you have redundant switches.

# %% [markdown]
# And that is often desirable because it gives you some fault tolerance.

# %% [markdown]
# If one switch goes down, another one is available. And this creates an alternate path to get to the ultimate destination.

# %% [markdown]
# But this redundancy can introduce an additional problem known as switching loops. And this is because switches learn where any given system is in terms of having to forward the packets. So as each switch discovers that any particular system is accessible over two different paths, it can end up simply cycling that packet around in an endless loop. And that can very quickly bring a network down.

# %% [markdown]
# So the Spanning Tree Protocol allows you to implement a loop-free but yet still redundant topology by assigning roles to the switches.

# %% [markdown]
# And the available roles are the root bridge, the root port, a designated port and a non-designated port.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Now the switch itself is either a root bridge or a non-root bridge.

# %% [markdown]
# And then on a root bridge you will always see designated ports specifying that this port is the path to this segment. [A diagram shows two segments, Segment 1 and Segment 2, connected by two switches, the Root bridge and the Non-root bridge. Designated ports on the Root bridge connect to each segment. On the Non-root bridge, a Root port connects to Segment 1 and a Non-designated port connects to Segment 2. ]

# %% [markdown]
# A non-root bridge, in essence, does not make any decisions as to how traffic will be moved. It just has its own root port for that switch.

# %% [markdown]
# But then we see a non-designated port which, in simple terms, is a port that's turned off.

# %% [markdown]
# So the root port is on, the non-designated port is off. So since we see one of them closed, if you will, that prevents the looping from happening.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Spanning Tree Protocol (STP) - 802.1d Standard (Slow)
# ***

# %% [markdown]
# Now the original Spanning Tree Protocol was defined by 802.1d.

# %% [markdown]
# And by default, it took 50 seconds for a port to fully transition from the blocking state, or that non-designated, to the forwarding state, or the root.

# %% [markdown]
# And, of course, that was a significant delay.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Rapid Spanning Tree Protocol (RSTP) - 802.1w Standard
# ***

# %% [markdown]
# So a newer version of the spanning tree known as Rapid Spanning Tree Protocol, or RSTP, was introduced in 1998 And defined by the 802.1w standard.

# %% [markdown]
# And RSTP can reconverge all of the states of the ports in approximately three seconds, so a significant improvement with RSTP.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Rapid Spanning Tree Protocol (RSTP) - Configuration
# ***

# %% [markdown]
# Now it implements this configuration by advertising whats known as Bridge Protocol Data Units or BPDUs.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### RSTP - Bridge Protocol Data Units (BPDUs)
# ***

# %% [markdown]
# When a switch first boots up it starts sending its own BPDUs.

# %% [markdown]
# When it learns the identity of the root bridge, which is something you configure, only the root bridge continues to source out BPDUs. In other words, all of the other switches withdraw.

# %% [markdown]
# The BPDUs are then forwarded throughout the network to control the state of any given port. And those four states are:
#
#
# i. Blocking
#
#
# ii. Listening
#
#
# iii. Learning
#
#
# iv. Forwarding

# %% [markdown]
# So it has to transition through each of those before it will effectively become a forwarding port or one that handles traffic.

# %% [markdown]
# So it is blocked by default. But if a switch realizes that another switch has gone down, then it can effectively transition so that the blocking port becomes available. And, of course, it can continue to provide services so that you don't lose the entire network with the loss of that switch. Because, again, that's why you implemented the redundancy in the first place.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Bridge Protocol Data Units (BPDU) Guard
# ***

# %% [markdown]
# Now there are also some guards in place with BPDUs.

# %% [markdown]
# And one is specifically known as the BPDU Guard.

# %% [markdown]
# Which prevents switching devices from connecting to any other switching device that has PortFast-enabled ports.

# %% [markdown]
# A PortFast-enabled port is one that immediately sets itself to a forwarding state instead of going through those four state changes that we just saw. This reintroduces the possibility of the loop occurring.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Root Guard
# ***

# %% [markdown]
# And then root guard is then next one.

# %% [markdown]
# And this, quite simply, prevents switches from becoming a root switch in the first place.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Loop Guard
# ***

# %% [markdown]
# And, finally, loop guard improves the stability in preventing bridging loops by adding another state, if you will, we just talked about those four states.

# %% [markdown]
# But if the non-designated port with this feature enabled stops receiving BPDUs it kind of assumes that there is a problem.

# %% [markdown]
# For example, another switch has gone down. But instead of going through the four states at that point, it places itself into what's known as a loop inconsistent but still-blocking state.

# %% [markdown]
# Basically, to give the other switch time to come back.

# %% [markdown]
# After a pre-configured amount of time, it will then go through the four states of blocking, listening, learning and forwarding before it actually implements itself as a forwarding port.

# %% [markdown]
# So it just gets you that extra step to allow the original switch to come back online.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Conclusion - Spanning Tree Protocol - Redundancy for Fault Tolerance
# ***

# %% [markdown]
# But, ultimately, the Spanning Tree Protocol is for when you do want redundancy for fault tolerance purposes. But you still want to have a network that is, of course, not going to immediately go down because these loops are occurring.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="mitigationTechniques6SwitchPortProtection"></a>
# ***
# ###### 6. Switch Port Protection
# ***

# %% [markdown]
# After completing this topic, you should be able to: ``recognize switch port protection such as ARP poisoning, DHCP snooping, and MAC filtering``

# %% [markdown]
# In this presentation we'll take a look at some switch configuration options pertaining to security, beginning with DHCP snooping.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Dynamic Host Configuration Protocol (DHCP) Snooping
# ***

# %% [markdown]
# Almost every environment these days will implement DHCP in one form or another.

# %% [markdown]
# So DHCP snooping is used to enforce security in a DHCP network and is configured at the switch port itself.

# %% [markdown]
# It uses DHCP information to determine whether or not any given DHCP server is acceptable.

# %% [markdown]
# And if it's deemed to be unacceptable, it quite simply drops the traffic. And this ensures that only authorized DHCP servers are used. Or perhaps more to the point, it prevents unauthorized DHCP servers from offering IP addresses to the clients.

# %% [markdown]
# So using a fairly simple example, let's assume you have a single DHCP server. And you have it plugged into physical switch port number one. As such, that switch will expect DHCP traffic to pass only over that port. So if someone attempts to create a rogue DHCP server, to hand out bogus IP addresses, it would, of course, have to be plugged into a different physical switch port. At which point the switch would say, wait a second, I'm not supposed to be seeing DHCP traffic over that port. Therefore, that server is unauthorized and it quite simply drops the traffic.

# %% [markdown]
# Now, I should also mention that if you are in a Windows Active Directory environment and you are using a Windows server for DHCP. Then Active Directory itself can also authorize that DHCP server. And again, more to the point, your Active Directory clients will not listen to a DHCP server that has not been authorized. But that's much more of a logical configuration, again, only within Active Directory.

# %% [markdown]
# There are many other servers, many other devices that can handle DHCP services. Routers, other operating systems can easily perform that task. So this is a much lower level configuration, if you will, right on the switch port. And, again, it simply would not care what you are using for your DHCP services. It is based entirely on the physical port itself. And only those configured to be acceptable will pass the DHCP traffic.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Address Resolution Protocol (ARP) Poisoning
# ***

# %% [markdown]
# ARP poisoning is another option you can configure.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Dynamic ARP Inspection
# ***

# %% [markdown]
# And this uses a protocol known as Dynamic ARP Inspection.

# %% [markdown]
# This is also configured on the switch port.

# %% [markdown]
# And again, just prevents ports from passing traffic where the IP address and the MAC address don't match what's in a trusted database of stored pairings.

# %% [markdown]
# And this is something that's built at runtime in combination, in many cases, with DHCP snooping.

# %% [markdown]
# Because once the DHCP server issues out an authorized IP address to a client, then it registers the fact that this MAC address is currently using this IP address. And basically that is entered into a trusted database. So that if somebody attempts to poison the cache by altering the values of the cache, the switch can say, nope, that does not match the pairing that I see in the trusted database. So ultimately this defends against ARP poisoning attacks.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### MAC Filtering
# ***

# %% [markdown]
# MAC filtering can also be implemented.

# %% [markdown]
# And this uses a whitelist to allow only specified machines to access the network.

# %% [markdown]
# It's also configured at the switch and does require a list of MAC addresses to be maintained.

# %% [markdown]
# So there can be some administrative overhead associated with this.

# %% [markdown]
# But if your environment is quite static, in other words, you aren't seeing a whole lot of change with respect to the systems that come and go. Then you certainly can configure these MAC addresses. And, in essence, anything that is not on the list will not be allowed to connect.

# %% [markdown]
# That also can help to prevent the rogue DHCP server. If it's a system that is just brought in by someone attempting to circumvent your security. And that MAC address of that system, whatever it is, is not on the whitelist, then it will not be allowed to participate in network communications.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### VLAN Assignment
# ***

# %% [markdown]
# And finally, you can implement VLAN assignment.

# %% [markdown]
# And this involves segregating traffic into separate VLANs.

# %% [markdown]
# So you can add another layer of security, as opposed to having everything within the same VLAN. You quite simply decide which types of resources maybe should be isolated based on some kind of category. So you can control access to your network resources independently of the underlying topology. Because we are, at the end of the day, all still plugged in into the same physical switches. But I can isolate my servers from my clients and/or perhaps particular services that they offer into separate VLANs.

# %% [markdown]
# So, again, it's just another layer of protection. Rather than having everything exposed within the same VLAN, a little bit of isolation certainly will never hurt.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Conclusion - Configurations at the Switch Level
# ***

# %% [markdown]
# So by implementing these different types of configurations at the switch level, you can improve the overall security of your environment.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="mitigationTechniques7NetworkSegmentation"></a>
# ***
# ###### 7. Network Segmentation
# ***

# %% [markdown]
# After completing this topic, you should be able to: ``describe network segmentation techniques such as DMZ and VLAN``

# %% [markdown]
# In this presentation, we'll take a look at various methods that can be used to implement network segmentation or, quite simply, dividing your network up.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Subnetting
# ***

# %% [markdown]
# Now there are several options, but we'll begin with subnetting. [A diagram shows a network layout. Router 1 is connected to the Internet, and to Routers 2 and 3. Between Routers 1 and 2 is Subnet 1. It starts at 50.5.11.1 and ends at 50.5.11.5, and contains three PCs with addresses of 50.5.11.2, 50.5.11.3, and 50.5.11.4. Between Routers 2 and 3 is Subnet 2. It starts at 50.5.12.65 and ends at 50.5.12.69, and contains three PCs with addresses of 50.5.12.66, 50.5.12.67, and 50.5.12.68. After Router 3 is Subnet 3. It starts at 50.5.13.82 and contains three PCs with addresses of 50.5.13.83, 50.5.13.84, and 50.5.13.85.]

# %% [markdown]
# And if you chose this approach, the idea is that you generally have a fairly large network that just needs to be divided up into these smaller subnets.

# %% [markdown]
# Now once you do this, you do have to ensure that you have the appropriate number of routers to handle the interconnectivity of all of those subnets.

# %% [markdown]
# So you generally have to try to strike a bit of a balance between the number of subnets and their size, and the number of routers that need to be implemented.

# %% [markdown]
# So looking at the two extremes, for example, let's just say this was a very large network with tens of thousands of computers, that's a little bit much. You would only need one router to handle all of the traffic of that network, for example, to connect it to the Internet.

# %% [markdown]
# But the traffic within the network would be rather overwhelming. So we decide to break it down into smaller units. But any two subnets that are defined need a router in between them to handle the interconnection. So that's the balance. I want smaller networks but I don't want them to be so small that I now have to implement dozens upon dozens of routers.

# %% [markdown]
# So, ultimately, try your best to strike that balance. But you typically determine the placement of the computers within a subnet based on how they communicate.

# %% [markdown]
# In other words, if the systems in the Subnet 1 communicate with each other most of the time, then they should be in the same subnet.

# %% [markdown]
# If they need to communicate with systems on Subnet 2, they certainly can, because the router is there. And that can carry on to Subnet 3 and so on, but that's the basic approach. Try to identify the systems that communicate with each other most often and place them within their own subnet.

# %% [markdown]
# That isolates their traffic within that subnet and you have less traffic passing between the routers.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Subnetting Schemes
# ***

# %% [markdown]
# Now if you are going to subnet, there are a few different schemes, or approaches, if you will, in terms of determining the configuration.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Subnetting Schemes - Logically - Physically
# ***

# %% [markdown]
# Logically, for example, by the IP addresses that you want to implement.

# %% [markdown]
# Or, physically, for example, the number of routers, or the actual placement of the routers.

# %% [markdown]
# Now ultimately, at the end of the day, the logical and the physical will have to match up.

# %% [markdown]
# In other words, if I decide these are the address configurations I'm going to use, you will have to place a router in between every two subnets.

# %% [markdown]
# But it's just how you begin the process, really. So you can configure which addresses to use then place the routers appropriately. Or you can determine the number of routers you want to manage and place them, then determine the address configuration.

# %% [markdown]
# But, as mentioned, at the end of the day, they'll have to match up.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Subnetting Schemes - Workgroups
# ***

# %% [markdown]
# Now you can also approach this by workgroups.

# %% [markdown]
# Meaning that you can separate the accounting computers from the rest of the network computers, or the sales, or the management, or really any kind of departmental division.

# %% [markdown]
# And that, in essence, again, is based on the fact that accounting computers will spend most of their time communicating with other accounting computers.

# %% [markdown]
# And you might also just consider geography, by building or locations, such as a university campus. And that does tie in with the physical as well, but on a much larger scale.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### VLANs
# ***

# %% [markdown]
# [A diagram shows a VLAN network layout. There are three groups of PCs. The PCs in each group are connected to each other. Each group is connected to a VLAN switch. The Internet connects to Wan 1, another switch, which connects to the internal VLAN switch. ]

# %% [markdown]
# Now another option is to implement VLANs. And in this configuration, it does look like subnets.

# %% [markdown]
# We do see each individual segment.

# %% [markdown]
# But what distinguishes this is the fact that this could all be the same subnet.

# %% [markdown]
# In terms of IP address configuration, every system within this configuration could fall within the same network address.

# %% [markdown]
# VLANs allow you to still separate out those systems that communicate with each other most often into their own little sections without having to route between them. Because it's all still the same network address.

# %% [markdown]
# Now you could create a VLAN with its own separate subnet, that's fine. But if they are also separate subnets, you would still need routers to communicate between them or across the subnets.

# %% [markdown]
# So with VLANs, you can separate them without having to route.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Demilitarized Zone Segments
# ***

# %% [markdown]
# [A diagram shows Demilitarized Zone Segments. PCs in an internal network are connected to a Router, which connects to a Firewall. The Firewall connects to another Firewall, which is connected to the Internet. In between the two Firewalls is the Demilitarized Zone Segment. Devices in DMZ include Routers, IDS/IPS, etc, Web Servers, Mail Servers, VPN Servers. ]

# %% [markdown]
# A demilitarized zone is another option. And this is generally implemented when you have systems that need to be exposed to the Internet but you don't want to expose your internal network directly to the Internet.

# %% [markdown]
# So, typically, you see two firewalls.

# %% [markdown]
# One that does still protect the systems that needs to be exposed to a degree. In other words, we are still only allow the appropriate protocols and ports.

# %% [markdown]
# But if those systems that did need to be exposed were on the internal network, then you would, in essence, have to expose your entire internal network.

# %% [markdown]
# So that just isn't a very secure configuration. We place another firewall between the internal network and the demilitarized zone. And then we place the devices such as the routers, the intrusion detection and/or prevention systems. And then the servers, such as web servers, mail servers and VPN servers in that DMZ segment.

# %% [markdown]
# And that isolates them from the internal network and from the Internet.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Network Address Translation
# ***

# %% [markdown]
# [A diagram shows Network Address Translation. Three blocks of addresses - 10.0.0.0 to 10.255.255.255, 172.16.0.0 to 172.31.255.255, and 192.168.0.0 to 192.168.255.255 connect to Network Address Translation. It sends a Single Unique IP address to the Internet. ] Now network address translation isn't so much something that you implement within the internal environment. This more or less just separates you're entire private network from the public Internet.

# %% [markdown]
# So when you have private IP addresses in use on the inside that need to get to the public internet, they cannot include their own private address as the return address, from the perspective of the Internet.

# %% [markdown]
# If a web server on the Internet, for example, receives a request from a system that has its return address as 10.0.0.10, for example, then that web server on the Internet will never forward that packet back out to the public Internet.

# %% [markdown]
# In essence, not know how to get that packet back to where it came from.

# %% [markdown]
# So network address translation is implemented on the router.

# %% [markdown]
# And the router strips off the private address from which the packet originated and replaces it with the public address of its Internet-facing interface.

# %% [markdown]
# So all packets from the Internet going back all see the single unique public IP address of the router as the return address.

# %% [markdown]
# Then the router forwards the packet appropriately back to the system that requested it in the first place.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Access Control Lists (ACL)
# ***

# %% [markdown]
# And finally, access control lists can be implemented for segmentation.

# %% [markdown]
# You can use these on firewalls and routers.

# %% [markdown]
# And used for essentially what's known as pessimistic configurations, meaning that we'll deny everything except for those that are explicitly allowed.

# %% [markdown]
# And we can allow or deny that network traffic based on the MAC address, the IP address, the protocol type and/or the port number.

# %% [markdown]
# So it is quite simply, explicitly saying, this traffic is allowed, anything else is not allowed. And that can also help to divide up the network in terms of which traffic will be allowed to travel across any given segment.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Conclusion - Segmentation is about Isolating Systems to reduce Traffic
# ***

# %% [markdown]
# So you can use a combination of any or all of those in terms of segmentation, but, ultimately, it's about isolating systems and trying to reduce the amount of traffic as much as possible.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="mitigationTechniques8PrivilegedUserAccounts"></a>
# ***
# ###### 8. Privileged User Accounts
# ***

# %% [markdown]
# After completing this topic, you should be able to: ``understand when to use privileged user accounts``

# %% [markdown]
# In this presentation, we'll take a look at the principle of least privilege, which is a fundamental characteristic of access control in just about every networking environment.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Least Privilege
# ***

# %% [markdown]
# And it means that the privileges you receive are limited to only those necessary to perform your job, a specific task, or a particular function.

# %% [markdown]
# And this ensures that only those assigned functions can be performed. While in turn, limiting the amount of harm that could be caused by a user or a system.

# %% [markdown]
# So for example, if it has been determined that any given user should be able to create a user account, or maybe reset passwords in, let's say, their department. Then you can give them just that ability without making them a full administrator.

# %% [markdown]
# Of course, someone who is a full administrator can perform that same task. But it's not necessary to make everyone a full administrator just because they need those abilities.

# %% [markdown]
# In almost every environment those privileges are quite granular. In other words, you can dole them out. You can say here, here are some privileges. And maybe those will add up as you gain more experience and you become more trustworthy. You will likely get more privileges.

# %% [markdown]
# But you, in essence, would not go from a regular user straight to a full administrator within the span of a day, for example. You get these permissions gradually.

# %% [markdown]
# So of course, you need to determine which privileges are necessary. So this involves reviewing the job responsibilities and then determining the minimum set of privileges.

# %% [markdown]
# You then restrict the user to those privileges and you can also deny other ones, and this minimizes security policy breaches.

# %% [markdown]
# So any given privilege can be explicitly granted to a user. But it can also be explicitly denied to ensure that they don't inherit the ability by joining or being placed in a group, and that's very common. You typically assign permissions and privileges to groups, not necessarily to individual users.

# %% [markdown]
# So if there is a group that has been granted a privilege, and a user then ends up in that group, by default they inherit the privilege. But you can ensure that they don't inherit the privilege by explicitly denying it. If you explicitly deny something to a user and they still join a group, that deny will override the inherit. So this again minimizes the chance that somebody might just inherit abilities that they shouldn't have.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Considerations - Use Groups
# ***

# %% [markdown]
# So when it comes to some of the considerations, as I just mentioned, it is generally a common practice to use groups.

# %% [markdown]
# And the idea here is that it's just easier to manage groups of users than it is to manage, let's say, hundreds or thousands of individuals.

# %% [markdown]
# So this ensures that users and applications are effectively placed into groups to streamline the permissions assignments.

# %% [markdown]
# Now, it's not always the case that you should use groups. It depends on the size of your environment. For example, in a smaller environment, you might only have one person that maybe should have this set of privileges. That's perfectly fine, but you don't want to have to be doing that over, and over, and over again for just individual, after individual, after individual. Particularly if the privileges, and/or the permissions they are receiving are more or less the same.

# %% [markdown]
# So if you determine these ten people should all have these same privileges and abilities, then place them into a group, and grant the ability to the group. Then everyone in the group, by default, inherits that ability. And again, this just makes it easier to manage and easier to control.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Considerations - Use the Accounts as Intended
# ***

# %% [markdown]
# Certainly use the accounts as intended.

# %% [markdown]
# Ensure that administrators only use their administrative accounts for the tasks that need those privileges.

# %% [markdown]
# Clearly, there has to be someone who is the highest level of administrator. And there can be one, or many full administrators.

# %% [markdown]
# But what you don't want them doing is using those administrator accounts all the time, day in, day out. They shouldn't just be browsing the Internet and checking their email and things like that with a full on administrative account. Because if they just do something as seemingly innocent as just getting up from their computer to go get a coffee, if they don't lock that system, then there is a system up and running with a full administrator logged on. Anyone else could come in behind them and do just about anything.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Considerations - Standardised Accounts
# ***

# %% [markdown]
# So you also want the standardized accounts.

# %% [markdown]
# Define a number of account types based on the user roles and assign as appropriate.

# %% [markdown]
# So again, the standardized accounts don't necessarily mean it is a standard user. It just has a standard applied to it. So this type of account always has these types of abilities.

# %% [markdown]
# And again, you can assign user roles to those types of accounts.

# %% [markdown]
# So maybe they're based on a particular job role or a particular function. And in essence, that account is always known to have those types of abilities. Therefore it is standardized, and you know what they can do and what they can't do.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Challenges
# ***

# %% [markdown]
# Now this does present some challenges, of course.

# %% [markdown]
# In larger environments you can have hundreds of thousands of users. So it is difficult to manage.

# %% [markdown]
# But this again is where groups can certainly make things easier, because you would not want to be applying different and varying sets of privileges across every single individual account. You group them together and you manage them as groups to simplify things.

# %% [markdown]
# You might have multiple geographical locations. And there can be challenges there, because some of those locations might not have full on administrators. They have sort of junior or sub-level administrators. But if you are the highest level administrator, you have to remote in from time to time and configure things there. But the abilities, of course, might vary depending on the geographical location. For example, certain locations might be considered to be more secure than others. So you have to gauge where you need to focus your attention.

# %% [markdown]
# You should always implement regular auditing to ensure successful implementation.

# %% [markdown]
# And auditing is always just keeping track of what has been going on. So we can identify if there were any breaches, or at least something that seems out of the ordinary.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Conclusion - Err on the side of Caution is a better approach than giving everyone Full Access to Everything
# ***

# %% [markdown]
# So, of course, there are always various access requirements. And it will often vary by the user with respect to the files they need, the applications they need to run, and the servers they access. So again, with so many users, it can become difficult to know, well, who is supposed to be able to do what?

# %% [markdown]
# But by implementing the principle of least privilege, at least you are ensured, to a degree, that things are relatively secure.

# %% [markdown]
# In other words, if you took the opposite approach and you gave everyone way too many permissions, then things would be going wrong all over the place. Because people would be able to do things that they should not be able to do.

# %% [markdown]
# So you err on the side of caution. If someone says, I need access to this file, or this server, or this application. And they are getting denied, well, that's better than them getting in when they aren't supposed to. You can review the situation and determine, if this user needs access, go ahead and give it to them. But again, erring on the side of caution is a much better approach than giving everyone full access to everything.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="mitigationTechniques9FileIntegrity"></a>
# ***
# ###### 9. File Integrity
# ***

# %% [markdown]
# After completing this topic, you should be able to: ``describe file integrity``

# %% [markdown]
# Another aspect of mitigating risks in your environment is maintaining file integrity.

# %% [markdown]
# And this is a process of protecting a file from unauthorized changes due to things such as intrusion or attack.

# %% [markdown]
# Of course, files will generally change fairly frequently, but in many cases, those are authorized changes. So it's the ones that are unauthorized that you need to try to prevent.

# %% [markdown]
# Now, file integrity can be altered after it is created during things such as its curation.

# %% [markdown]
# In other words, there is normally someone who is responsible for that file. They look after it. They maintain it.

# %% [markdown]
# So you need to try to ensure that whatever changes are happening are allowed to happen.

# %% [markdown]
# You might also find this happening right before a file is archived or backed up. In a lot of cases, people might not pay as much attention to the security of a backed up file, as opposed to the active file.

# %% [markdown]
# So if someone can access the backed up copy, they might be able to exchange the contents of that file, again, in an unauthorized manner, and/or maybe disseminate a copy that they have compromised.

# %% [markdown]
# So there are a number of instances where the integrity of any given file can be compromised.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Hashing
# ***

# %% [markdown]
# Now hashing is a means to protect against these unauthorized changes.

# %% [markdown]
# So you can check the file integrity by comparing two versions of a data set.

# %% [markdown]
# And again, the idea behind a hash is that it's just an algorithm that uses the existing data in the file to generate some kind of answer.

# %% [markdown]
# So if the data itself changes in any way, the hash value will also change. So if you know that this file should not change, you can look at the hash and basically compare it to the state was in, let's just say, yesterday versus today. And if the hash changed, then the file itself also changed.

# %% [markdown]
# Now some common hashing algorithms include MD5, SHA version one and SHA-256. Now that's not a version, that's the cipher strength of the hashing algorithm.

# %% [markdown]
# But regardless of which algorithm you use, the hash will change if the contents change.

# %% [markdown]
# So that's how you can verify whether or not the integrity has been maintained.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### File Integrity Monitoring
# ***

# %% [markdown]
# Now in terms of monitoring for file integrity, this is typically an internal control or process that is used to validate the integrity of your files, in essence, that current state versus a baseline.

# %% [markdown]
# This is how they should be. What is the state of them now compared to that baseline?

# %% [markdown]
# So you can try to detect those changes. So you can monitor these files and, in many cases, that can be automated. There are a number of different internal applications or processes that you can use to ensure that files aren't changed.

# %% [markdown]
# Or, of course, it can be manual if you have a very particularly important file, and you're not overwhelmed by the number of files, and/or the number of changes that are happening.

# %% [markdown]
# Then you can manually keep an eye on things, and you can always check the validity of that file.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### File Change
# ***

# %% [markdown]
# So then with respect to the changes to the file itself that might impact your IT infrastructure, you need to be on the lookout for changes, not only to the file itself, but the credentials of users.

# %% [markdown]
# Have they changed in any way? In other words, has some kind of new account appeared that has the ability to access the file?

# %% [markdown]
# If so, maybe that account was unauthorized.

# %% [markdown]
# You certainly need to check the hash values.

# %% [markdown]
# Also look at the core attributes of the file. And a very simple example there might be if a file was originally set to be read-only and then all of a sudden that attribute was removed. Then somebody is attempting to change the contents of that file.

# %% [markdown]
# Any configuration values for the file, particularly if it's something like a database, wherein you need to get to the application itself to access the file, has the configuration of the database server changed at all?

# %% [markdown]
# Of course, the privileges, the permissions, have they changed? What are the overall security settings for the server that hosts the file, the folder in which it resides and, of course, the file itself?

# %% [markdown]
# So you always need to be mindful of, in essence, what kind of permissions people have to this file. And you can implement, again, a number of ways to monitor this.

# %% [markdown]
# But it is flat out, keeping track. Knowing the state of how things should be versus how they might be at any particular point in time will help you to identify whether or not its integrity has been compromised.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="mitigationTechniques10RoleSeparation"></a>
# ***
# ###### 10. Role Separation
# ***

# %% [markdown]
# After completing this topic, you should be able to: ``describe role separation``

# %% [markdown]
# In this presentation, we'll take a look at separation of duties, which is an administrative approach whereby it requires two or more persons to perform a specific task.

# %% [markdown]
# Now, each person is an active participant in the task, but typically one person will take on a supervisory role.

# %% [markdown]
# But this restricts the amount of power held by any single individual.

# %% [markdown]
# For example, no one reports to themselves. And this can help to prevent conflicting responsibilities, and is often a key concept of internal controls. Ensuring that you don't have one person who is responsible for everything, but then, in turn, reports to no one.

# %% [markdown]
# So, for example, you might have a scenario whereby an individual is responsible for designing and implementing network security. But that person should then not be able to perform network security testing, conduct security audits, monitor the security, and/or report on the security. At least not in an official capacity. Because this would be that very example where, if that person did everything, they are effectively answering to no one. So being that they designed it and implemented it, if they don't have to answer to anyone then, of course, they could have left all all kinds of intentional back doors, so that they, themselves, could breach the security.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Conflict of Interest
# ***

# %% [markdown]
# So the primary goal of implementing separation of duties is the prevention of conflict of interest. Wrongful acts, fraud, abuse, and in many cases, just errors.

# %% [markdown]
# People will legitimately make mistakes from time to time. But if you have more than one person involved, then it's less likely that error will go unnoticed.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Detection of Control Failures
# ***

# %% [markdown]
# You also want to try to implement detection of control failures, such as security breaches, information theft, and circumvention of the controls themselves.

# %% [markdown]
# Again, somebody simply trying to bypass any kinds of security protocols or covering their tracks, if you will, with respect to the confidentiality, the integrity and the availability of the data you are protecting.

# %% [markdown]
# One example there is if you create something like a security policy which outlines all of the security features, and then implement it, you can monitor if the policy itself is ever changed. So even though you have implemented the policy, and you can report and say yes, this policy has now been implemented, and everybody's happy. Someone who has the ability to change the policy, of course, can do so. But you can monitor for changes to the policy itself. So if someone else is responsible for monitoring that change to the policy, they would know. They would see that the policy has changed and they can then investigate.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Risk Assessment
# ***

# %% [markdown]
# Now, this may not be required for all business processes, so you should typically conduct a risk assessment. Consider compensating controls, such as audit logs and detection of irregularities.

# %% [markdown]
# So for example, in dual control situations, you can have a system configuration task that must then also be authorized by two authenticated system administrators.

# %% [markdown]
# In other words, people who should have the ability to approve this have to do so. Then, once it is approved and they are aware of what is being implemented, of course they can go back and verify, after the fact, that the system configuration task itself was performed and performed correctly.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Overlook Logging
# ***

# %% [markdown]
# And, also, you don't want to overlook the importance of logging, because you can't always be on top of everything all the time.

# %% [markdown]
# So logging tracks system configuration changes. And, in fact, that's the example I mentioned earlier, whereby you might implement a policy and then also track changes to the policy.

# %% [markdown]
# Well, the change would be something that would be logged. You would typically would not be there monitoring the policy 24 hours a day, 7 days a week.

# %% [markdown]
# So you have to rely on the log to indicate that this happened. So they, themselves, should also be protected and reviewed, periodically. So that if these people who are making changes are going to be reviewed, then they should not be the ones who are reviewing those logs.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Conclusion - Determine show should perform Tasks
# ***

# %% [markdown]
# So ultimately, it's all about trying to determine who should be able to perform these tasks, because somebody needs to. But there should always be someone else involved.

# %% [markdown]
# Someone else who has a say, and, of course, can oversee some of these operations to ensure that they are implemented correctly.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="mitigationTechniques11AccessControlLists"></a>
# ***
# ###### 11. Access Control Lists
# ***

# %% [markdown]
# After completing this topic, you should be able to: ``recognize when to use access control lists``

# %% [markdown]
# In this presentation, we'll take a look at access control lists. And there are a few different implementations of these, and we'll certainly take a look at them. But this is a method by which you can mitigate some of your security concerns by quite simply stating who is allowed to access something and/or who is not allowed.

# %% [markdown]
# So it's a very fundamental approach in terms of security.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### File System Access Control Lists
# ***

# %% [markdown]
# Now, we'll begin with file system access control lists, whereby you can secure the files and folders on a server with respect to the security principals of your environment.

# %% [markdown]
# Now, they include the users, the groups to which they belong, and even the computers.

# %% [markdown]
# Now, of course, a computer all by itself does not access a file, per se. But most networking environments have services that, in essence, are aware of the computers, just like they are aware of the users. So what you can do is to ensure that if someone is sitting at a particular computer. Then that computer is not allowed to be used to access these folders or these files. So it's not only based on who you are that can determine your access, but also where you are.

# %% [markdown]
# And the fundamental approach is to, quite simply, grant or deny access.

# %% [markdown]
# And denying is not always necessary in terms of just keeping someone out. In other words, if you have not been granted permission, then it does not assume to allow you. In fact, it's the opposite, it assumes to not allow. So why do you need to deny access if you aren't allowed anyway? Because of what's known as inheritance.

# %% [markdown]
# When you are given permission as a user, then yes, you are allowed to access that file. But in many cases permissions are given to groups. Because in larger environments, it's much easier to place hundreds of users into a group where all of the members need access to the same files. That way you only need to give permission one time to the group, and everyone in the group inherits that permission. And there's also inheritance of files and folders themselves.

# %% [markdown]
# If you have permission to folder A, which then has several subfolders within it, then that permission flows down through the hierarchy. So that you have permission to everything throughout the entire hierarchy.

# %% [markdown]
# But, in some cases, that's not applicable. You might want a user in a group because it gives them access to a lot of other resources. But there could be a few folders or files that the group is allowed to access that this particular user should not.

# %% [markdown]
# Maybe they're on a probationary period and they've just been granted access. And you generally wait for a little bit before they are given full access.

# %% [markdown]
# So they can be placed in the group, but that by default would give them permission. But then you can explicitly deny access to, we'll call them, the more sensitive folders or files.

# %% [markdown]
# And that explicit deny overrides the inherited permission.

# %% [markdown]
# And then the same thing could happen within a folder hierarchy. If you are given permission to parent folder A, by default you have permission to every child object within that. But you can explicitly go through the hierarchy and say, for this particular folder or file, I am going to explicitly deny access to someone. And that overrides the inheritance.

# %% [markdown]
# So typically denies are only used in those override scenarios. They don't have to be used to just keep someone out.

# %% [markdown]
# But if you do want to ensure very tight security over a particular file or folder, then you can explicitly deny. And that ensures that no matter what, that person or group will not have access. Explicit denies override inherited allows.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Access Control Lists (ACLs) - Computer Network
# ***

# %% [markdown]
# Now, there are other ways that ACLs can be used in a computer network.

# %% [markdown]
# For example, ACLs in networking allow or deny traffic through certain devices based on IP and port configurations.

# %% [markdown]
# So you can quite literally go to a router, for example, and say that it should not accept traffic from any other IP addresses other than the ones that you specifically allow.

# %% [markdown]
# And this ensures that it will not accept traffic, for example, from outside of your organization. In other words, someone is trying to intrude in and reconfigure the router, so this way it ensures this does not happen. You explicitly list the accepted IP address, and those ones are allowed.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### IP and Port Filtering
# ***

# %% [markdown]
# So also with respect to IP and ports, you can filter.

# %% [markdown]
# So not only is it a matter of just allowing access and/or communication from a specific address.

# %% [markdown]
# You can filter traffic based on the source and the destination port.

# %% [markdown]
# So where the traffic comes from and where it's going, and in this regard they are somewhat similar to firewalls. Because it's not so much the entire IP address, but rather the type of traffic.

# %% [markdown]
# So if it's a particular protocol and if it is a particular source and destination, you can allow it. But if it's something that you don't recognize, or don't like, or just don't want to have happen, of course, you can filter that traffic out.

# %% [markdown]
# So, again, it can be based on the address and/or the type of service that is passing through that device.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Blacklist and Whitelist
# ***

# %% [markdown]
# Now, you can also implement blacklists and whitelists.

# %% [markdown]
# And a blacklist is, in essence, an implicit allow of all other traffic except for those that are specifically and explicitly denied on the blacklist.

# %% [markdown]
# So, in essence, you say everything is okay, except for this, this, and this, that's the blacklist.

# %% [markdown]
# A whitelist is the complete opposite of that. A whitelist is an implicit deny.

# %% [markdown]
# In other words, deny everything except for those that are on the whitelist. So this is acceptable, this is acceptable, this is acceptable, nothing else is.

# %% [markdown]
# So you can take either approach, it really would come down to how many entries you have to create and/or manage. But in one way or another, you are still saying, this is acceptable, this is not. And all of those are different variations of access control lists, that which is acceptable and that which is not acceptable.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="mitigationTechniques12Honeypots"></a>
# ***
# ###### 12. Honeypots
# ***

# %% [markdown]
# After completing this topic, you should be able to: ``describe honeypots``

# %% [markdown]
# Now in this presentation, we'll take a look at Honeypots and Honeynets.

# %% [markdown]
# And the purpose is to ultimately detect, deflect, and counteract any kind of attack against your environment.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Decoy
# ***

# %% [markdown]
# By presenting what appears to be a legitimate but vulnerable system, but in fact, it's really just a decoy.

# %% [markdown]
# And this can be very useful in terms of gathering information, because you can literally see what type of attack is being launched what the methods are, and maybe even where it's coming from. So this can help you to identify information about the intruder themselves.

# %% [markdown]
# So the basic idea is, let's say you happen to be monitoring some network traffic, and you do actually catch some suspicious activity.

# %% [markdown]
# Of course, you could entirely block the attack by taking that system offline unplugging it from the network for example.

# %% [markdown]
# While that foils the attack, it doesn't allow you to gain any insight into the attack. So future attacks, of course, might still happen. So with the honeypot in essence you let them proceed with the attack because they are only operating against a decoy. So, you quite literally watch what happens. Now, this might just logged, of course, but the idea is that you actually see what they did, how they got in, what methods they are using so that you can better protect your environment in the future.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Firewall Design
# ***

# %% [markdown]
# Now you certainly need to consider what your firewall design is in terms of their placement.

# %% [markdown]
# Do you have firewalls on the inside of your organization as well as on the outside or just one or the other?

# %% [markdown]
# And or have you configured a demilitarized zone which is a buffer that sits between the Internet and your internal LAN.

# %% [markdown]
# Typically, systems such as Web servers need to be exposed to the internet, but you don't want them inside your corporate lab.

# %% [markdown]
# So you create this demilitarized zone which has a firewall facing the internet and another firewall facing the Internal network. And then those exposed systems in between, that's the demilitarized zone.

# %% [markdown]
# So quite often you would place the honey pots in the DMZ.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Honeynets and Honeyfarms
# ***

# %% [markdown]
# Now honeynets and honeyfarms are fairly similar you can see both of them are multiple honeypots, but a honeynet is something that you might see in a larger network. [A honeynet consists of two or more honeypots.]

# %% [markdown]
# And in essence presents the home network more so as the vulnerability maybe not any one specific system.

# %% [markdown]
# Whereas a honeyfarm is still a collection of honey pots but it's more so multiple individual targets not so much the network itself.

# %% [markdown]
# But you might hear those two terms used some what interchangeably. But in either case it's just a more robust implementation of vulnerable systems as opposed to just a single vulnerable system.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Honeypot Implementation
# ***

# %% [markdown]
# So honeypots are typically implemented by installing the appropriate software on those systems.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Honeypot Implementation - Glastopf
# ***

# %% [markdown]
# And Glastopf is an example that is an open source product which emulates a vulnerable web server and it can emulate thousands of vulnerabilities.

# %% [markdown]
# So this makes it very attractive to the attacker. It looks as though there is something that I can compromise. It offers GUI management for you as the administrator, reporting features so that you can see what kind of attacks have occurred against it. And it even supports updates so that as new vulnerabilities are revealed it can then emulate those as well.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Honeypot Implementation - Specter
# ***

# %% [markdown]
# Specter is another example, which is a commercial product, and it's also GUI-based.

# %% [markdown]
# It also updates its own content.

# %% [markdown]
# And this is more so used for tracing so that you can actually see the steps that were taken, the protocols that were implemented to obtain access to that system.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Ghost USB
# ***

# %% [markdown]
# Ghost USB is a free USB emulation software that mounts as a fake USB drive, because many malware applications will try to infect a flash drive as soon as it's inserted.

# %% [markdown]
# So, this tricks the malware into believing that a flash drive has been inserted, and, as such, it can capture and analyze what that malware is actually doing without harming the system itself.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### KFSensor (Window-based)
# ***

# %% [markdown]
# And KFSensor is a Windows-based honeypot that in essence implements itself as an intrusion detection system that uses what's known as the snort signature engine, which is an intrusion detection system.

# %% [markdown]
# So, those are just the engines that are used to detect the unusual activity.

# %% [markdown]
# And this simulates vulnerable systems service on a Windows System so that it can present itself to things like Trojans.

# %% [markdown]
# It also offers various features, such as remote management. That Snort signature engine which handles the updates and the detection of course.

# %% [markdown]
# But the idea is again, to emulate various Windows networking protocols so that you can see what is actually happening when someone tries to circumvent or compromise those protocols.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Conclusion - Present a Decoy to allow Attacker Believe
# ***

# %% [markdown]
# So ultimately, again the idea is to just present this decoy and to allow the attackers to believe that they have succeeded in compromising your environment.

# %% [markdown]
# This allows you to gain more insight in types of attacks that you are most likely to face and of course, address them appropriately.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="mitigationTechniques13PenetrationTesting"></a>
# ***
# ###### 13. Penetration Testing
# ***

# %% [markdown]
# After completing this topic, you should be able to: ``recognize the benefits of penetration testing``

# %% [markdown]
# In this presentation, we'll talk about penetration testing or what is often just dubbed pen testing, for short.

# %% [markdown]
# But this is the process of actively, yet voluntarily, exploiting vulnerabilities with respect to the hardware and software you have implemented, the configurations you have. And even using social engineering techniques against your own users to, quite simply, find out what is the overall security of your organization.

# %% [markdown]
# So, as mentioned, this is done voluntarily with the consent of system owners.

# %% [markdown]
# Now in many cases, you might hire a third party to implement the testing, so you might have non-disclosure agreements in place.

# %% [markdown]
# But they, in essence, launch these attacks against your environment so that they can report back and say here is where we were able to compromise and here is where we were blocked.

# %% [markdown]
# So you, of course, can address the weaknesses.

# %% [markdown]
# Now this can be done manually or through a variety of automated processes and depending on the size of your environment, can also take a fair amount of time.

# %% [markdown]
# But in terms of the benefits, you get this overall picture as to how effective the security is in your organization.

# %% [markdown]
# Now there might be multiple application testing phases, again, it can take a while. And you do need to be mindful of potential disruptions to your production systems.

# %% [markdown]
# So they might launch some tests against just some maintenance or development systems first, just to see whether or not these vulnerabilities exist. But then they still have to ultimately try to compromise the production system. So in the event that they succeed, this, of course, could disrupt your environment.

# %% [markdown]
# But ultimately, you need to know these things.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Black Box
# ***

# %% [markdown]
# Now, there are a few different implementations, but a black box penetration test is, in essence, where the attackers themselves, the testers, don't really know anything about the target.

# %% [markdown]
# So they're kind of going in blind, if you will, hence the term black box.

# %% [markdown]
# But in many cases, that is the perspective of an attacker. They really don't know what it is that they might find, but they're looking for anything.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### White Box
# ***

# %% [markdown]
# A white box is the exact opposite, whereby the testers have details about the target.

# %% [markdown]
# So they are launching much more focused attacks against that target to find out if, of course, they can compromise it.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Conclusion - Penetration Testing
# ***

# %% [markdown]
# And, in many cases, penetration testing might be implemented as a combination of both black box and white box.

# %% [markdown]
# So some examples, of course, could include impersonating a help desk technician and calling an accounting clerk. So that would be a social engineering technique. Just flat out finding out if I can get this person to divulge sensitive information. Maybe it's trying to break into a Wi-Fi network using WPA Personal encryption. Maybe it's simply reviewing application code prior to its deployment. Or seeing if I can successfully crack user passwords. And, again, there can be a variety of techniques that might be used in that case but, ultimately, it's just different types of attacks. And reporting on what the results were, so that you can go back and say here is what we were able to do. We circumvented your security here, here, and here. We were not successful here, here, and here. So you now know where the weakness are and, of course, you can address those.

# %% [markdown]
# So penetration testing is very useful for tightening things up. And it's something that should also be done regularly. You shouldn't assume to configure everything one time then test it and basically go about your business from that point on thinking you will always be secure. It's something that you always need to keep on top of. And as things change and evolve, you should implement tests to keep up with those changes.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="practicemitigationTechniques"></a>
# ***
# ### Practice: Using Mitigation Techniques
# ***

# %% [markdown]
# After completing this topic, you should be able to: ``implement mitigation techniques``

# %% [markdown]
# i. Describe malware signature management.
#
#
# ii. Then to describe various methods of network segmentation.
#
#
# iii. Then to describe the principle of least privilege.
#
#
# iv. And finally to describe a honeypot.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="exercisemitigationTechniques"></a>
# ***
# ###### 1. Exercise: Using Mitigation Techniques
# ***

# %% [markdown]
# i. First task was to describe malware signature management.

# %% [markdown]
# And in essence malware programs, and intrusion detection systems use these signatures to detect threats. And once they are detected, the signature is applied to that threat so that their applications can pick them up. So vendors issue signature releases on an ongoing basis. In other words, they are kept as up to date as possible. So it's very important for your application to be configured so that it will go out and check for those updates. And, as such, it will be as current, as virus or the malware, whatever it is, or at least as current as it can be.

# %% [markdown]
# ii. Then we asked to describe various methods of network segmentation.

# %% [markdown]
# And for this you can implement subnets, VLANs, demilitarized zones, Network Address Translation and/or access control lists. All of those give you one way or another to subdivide your network into these smaller, more manageable units.

# %% [markdown]
# iii. Then we asked to describe the principle of least privilege.

# %% [markdown]
# And this involves granting only the necessary permissions to complete a particular task, but nothing more. In other words, if you only need to install software or update drivers or configure a user account, you generally do not need full administrative abilities. So the idea is to grant only those permissions that allow you to perform your job, and basically accumulate those abilities as you go, and as you gain more experience, but not right away.

# %% [markdown]
# iv. And then finally, we asked to describe a honeypot.

# %% [markdown]
# And this is essentially a decoy system used to entice attackers, while allowing you to monitor their activities, without exposing an actual system. So it's something that looks like a normal system to the attacker. But it's just software that emulates various types of vulnerabilities so that they hopefully will attack that system. And then you can quite literally watch what they're doing and discover which methods they used, in essence to, of course, try to patch that hole if you will. And address that vulnerability so that it does not happen with respect to attacking your real systems. So hopefully you made out all right with those questions. And if so, we are ready to move on to our next course.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="mitigationTechniquesTest"></a>
# ***
# ### ⚡ Test
# ***

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) >
# <a id="references"></a>
# ***
# ## References
# ***

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="appendix"></a>
# ***
# ## Appendix
# ***

# %% [markdown]
# ***
# ## END

# %%
from IPython.core.display import display,HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# # END JUPYTER NOTEBOOK
